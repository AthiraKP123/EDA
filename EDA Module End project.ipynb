# %% [markdown]
# ## Performing Exploratory Data Analysis of Employee Data
# Providing a dataset of employees working in ABC company. It consists of 458 rows and 9 columns. The company needs the detailed report and explanation of their employees in each team.
# #### Importing all required modules

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# #### Accessing the dataset

# %%
df=pd.read_csv("abc_company.csv")
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.head()
# Out:
#             Name            Team  Number Position  Age  Height  Weight  \
# 0  Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1    Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2   John Holland  Boston Celtics      30       SG   27  06-May     205
# 3    R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4  Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
#
#              College     Salary
# 0              Texas  7730337.0
# 1          Marquette  6796117.0
# 2  Boston University        NaN
# 3      Georgia State  1148640.0
# 4                NaN  5000000.0

# %%
df.tail()
# Out:
#              Name       Team  Number Position  Age  Height  Weight College  \
# 453  Shelvin Mack  Utah Jazz       8       PG   26  06-Mar     203  Butler
# 454     Raul Neto  Utah Jazz      25       PG   24  06-Jan     179     NaN
# 455  Tibor Pleiss  Utah Jazz      21        C   26  07-Mar     256     NaN
# 456   Jeff Withey  Utah Jazz      24        C   26     7-0     231  Kansas
# 457      Priyanka  Utah Jazz      34        C   25  07-Mar     231  Kansas
#
#         Salary
# 453  2433333.0
# 454   900000.0
# 455  2900000.0
# 456   947276.0
# 457   947276.0

# %%
df.describe(include ='all')
# Out:
#                  Name                  Team      Number Position         Age  \
# count             458                   458  458.000000      458  458.000000
# unique            458                    30         NaN        5         NaN
# top     Avery Bradley  New Orleans Pelicans         NaN       SG         NaN
# freq                1                    19         NaN      102         NaN
# mean              NaN                   NaN   17.713974      NaN   26.934498
# std               NaN                   NaN   15.966837      NaN    4.400128
# min               NaN                   NaN    0.000000      NaN   19.000000
# 25%               NaN                   NaN    5.000000      NaN   24.000000
# 50%               NaN                   NaN   13.000000      NaN   26.000000
# 75%               NaN                   NaN   25.000000      NaN   30.000000
# max               NaN                   NaN   99.000000      NaN   40.000000
#
# ...

# %% [markdown]
# ### Data story
# The describe function mainly shows the statistical information of the data. This mainly shows counts(which shows number of cells are filled), frequency, mean, standard deviation, minimum, 1st quartile, 2nd quartile / median, 3rd quatile, maximum, etc.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 458 entries, 0 to 457
# Data columns (total 9 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Name      458 non-null    object
#  1   Team      458 non-null    object
#  2   Number    458 non-null    int64
#  3   Position  458 non-null    object
#  4   Age       458 non-null    int64
#  5   Height    458 non-null    object
#  6   Weight    458 non-null    int64
#  7   College   374 non-null    object
#  8   Salary    447 non-null    float64
# dtypes: float64(1), int64(3), object(5)
# memory usage: 32.3+ KB

# %%
df.isnull().sum()
# Out:
# Name         0
# Team         0
# Number       0
# Position     0
# Age          0
# Height       0
# Weight       0
# College     84
# Salary      11
# dtype: int64

# %% [markdown]
# ### Data story
# The number of null information in each column. Data reveals that the columns 'College' and 'Salary' only have null values of 84 and 11 respectively while others have zero null values.So this needs to be replaced by any values preferrably mean median or mode.
# #### Replacing null values

# %%
df1=df.fillna(value={'Salary':'0','College':'Unknown'})
df1
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  06-Feb     180
# 1      Jae Crowder  Boston Celtics      99       SF   25  06-Jun     235
# 2     John Holland  Boston Celtics      30       SG   27  06-May     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22  06-May     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  06-Oct     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  06-Mar     203
# 454      Raul Neto       Utah Jazz      25       PG   24  06-Jan     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26  07-Mar     256
# 456    Jeff Withey       Utah Jazz      24        C   26     7-0     231
# 457       Priyanka       Utah Jazz      34        C   25  07-Mar     231
#
#        College     Salary
# 0    7730337.0  7730337.0
# 1    6796117.0  6796117.0
# ...

# %%
df.isnull().sum()
# Out:
# Name        0
# Team        0
# Number      0
# Position    0
# Age         0
# Height      0
# Weight      0
# College     0
# Salary      0
# dtype: int64

# %% [markdown]
# ### Data story
# Replaced null values in the columns "salary" and "College"  with the median values and  with the word "unknown" respectively.
# #### Finding duplicate values

# %%
duplicate = df[df.duplicated()]
duplicate
# Out:
# Empty DataFrame
# Columns: [Name, Team, Number, Position, Age, Height, Weight, College, Salary]
# Index: []

# %% [markdown]
# ### Data story
# There are no duplicate rows in the entire dataset
# #### Finding unique values in column "Team" and "Position"

# %%
df["Team"].unique()
# Out:
# array(['Boston Celtics', 'Brooklyn Nets', 'New York Knicks',
#        'Philadelphia 76ers', 'Toronto Raptors', 'Golden State Warriors',
#        'Los Angeles Clippers', 'Los Angeles Lakers', 'Phoenix Suns',
#        'Sacramento Kings', 'Chicago Bulls', 'Cleveland Cavaliers',
#        'Detroit Pistons', 'Indiana Pacers', 'Milwaukee Bucks',
#        'Dallas Mavericks', 'Houston Rockets', 'Memphis Grizzlies',
#        'New Orleans Pelicans', 'San Antonio Spurs', 'Atlanta Hawks',
#        'Charlotte Hornets', 'Miami Heat', 'Orlando Magic',
#        'Washington Wizards', 'Denver Nuggets', 'Minnesota Timberwolves',
#        'Oklahoma City Thunder', 'Portland Trail Blazers', 'Utah Jazz'],
#       dtype=object)

# %%
df["Position"].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %% [markdown]
# #### Q1. How many are there in each Team and the percentage splitting with respect to the total employees.

# %%
df1=pd.DataFrame({"Counts":df.Team.value_counts()}).reset_index()
df1['Short'] = df1['Team'].apply(lambda x: ''.join(word[0] for word in x.split()))
df1
# Out:
#                       Team  Counts Short
# 0     New Orleans Pelicans      19   NOP
# 1        Memphis Grizzlies      18    MG
# 2                Utah Jazz      16    UJ
# 3          New York Knicks      16   NYK
# 4          Milwaukee Bucks      16    MB
# 5            Brooklyn Nets      15    BN
# 6   Portland Trail Blazers      15   PTB
# 7    Oklahoma City Thunder      15   OCT
# 8           Denver Nuggets      15    DN
# 9       Washington Wizards      15    WW
# 10              Miami Heat      15    MH
# 11       Charlotte Hornets      15    CH
# 12           Atlanta Hawks      15    AH
# 13       San Antonio Spurs      15   SAS
# 14         Houston Rockets      15    HR
# 15          Boston Celtics      15    BC
# 16          Indiana Pacers      15    IP
# 17         Detroit Pistons      15    DP
# 18     Cleveland Cavaliers      15    CC
# 19           Chicago Bulls      15    CB
# 20        Sacramento Kings      15    SK
# 21            Phoenix Suns      15    PS
# ...

# %% [markdown]
# ### Data story
# Here is the total number of employees in each team and created an abbreviation for each team name so that it will be easier for data visualisation. Then craeted a new dataframe called "df1" to store only the required data such as Team name,Abbreviation, and the number of employees un each team.

# %%
plt.figure(figsize=(15, 10))
plt.bar(df1["Short"],df1["Counts"],color=plt.cm.tab20c.colors)
plt.title("No.of employees in each team")
plt.xlabel("Team")
plt.ylabel("No.of Employees")
plt.show()

# %% [markdown]
# Here is the visual representation of total employees in each team using bar chart. x-axis is used to represent the team name and the y-axis represents the total no of employees

# %%
df1["Percentage"] = (df1["Counts"]/df1["Counts"].sum())*100
df1
# Out:
#                       Team  Counts Short  Percentage
# 0     New Orleans Pelicans      19   NOP    4.148472
# 1        Memphis Grizzlies      18    MG    3.930131
# 2                Utah Jazz      16    UJ    3.493450
# 3          New York Knicks      16   NYK    3.493450
# 4          Milwaukee Bucks      16    MB    3.493450
# 5            Brooklyn Nets      15    BN    3.275109
# 6   Portland Trail Blazers      15   PTB    3.275109
# 7    Oklahoma City Thunder      15   OCT    3.275109
# 8           Denver Nuggets      15    DN    3.275109
# 9       Washington Wizards      15    WW    3.275109
# 10              Miami Heat      15    MH    3.275109
# 11       Charlotte Hornets      15    CH    3.275109
# 12           Atlanta Hawks      15    AH    3.275109
# 13       San Antonio Spurs      15   SAS    3.275109
# 14         Houston Rockets      15    HR    3.275109
# 15          Boston Celtics      15    BC    3.275109
# 16          Indiana Pacers      15    IP    3.275109
# ...

# %% [markdown]
# ### Data story
# created a new column named "Percentages" which shows the percentage split of employees.
# It is calculated by dividing the count of employees any one team with the total number of employees and then multiplied by 100 to get the percentage.

# %%
plt.figure(figsize=(11,6))
plt.plot(df1['Short'], df1['Percentage'], marker='o')
plt.title("Percentage split of employees")
plt.xlabel("Short")
plt.ylabel("Percentage")
plt.grid(True)
plt.show()

plt.figure(figsize=(6,6))
plt.pie(df1['Percentage'],labels=df1['Short'])
plt.title("Percentage split of employees")
plt.show()

# %% [markdown]
# ### Data Story
# From analysing the above line graph , it's clear that the team "New Orleans Pelicans" has more percentage split compared to other teams , Also there is a identical pattern for some teams starting from "BN(Brooklyn Nets)" to "DM(Dallas Mavericks)".
# #### Q2.Segregate the employees w.r.t different positions.

# %%
df["Position"].unique()
# Out:
# array(['PG', 'SF', 'SG', 'PF', 'C'], dtype=object)

# %% [markdown]
# ### Data story
# In the given dataset there are 5 different positions.
# which are PG, SF, SG, PF , C. now we have to seggregate the total employees with respect to these 5 different categories

# %%
df2=pd.DataFrame({"Counts":df.Position.value_counts()}).reset_index()
df2
# Out:
#   Position  Counts
# 0       SG     102
# 1       PF     100
# 2       PG      92
# 3       SF      85
# 4        C      79

# %% [markdown]
# ### Data story
# Number of employees in each category is mentioned above.

# %%
plt.bar(df2["Position"],df2["Counts"],color=plt.cm.tab20c.colors)
plt.title("No.of employees in each Position")
plt.xlabel("Position")
plt.ylabel("No.of Employees")
plt.show()

# %% [markdown]
# Visual representation of No of employees and their positions using bar plot. x-axis represents the position category and y-axis represents the no of employees..

# %% [markdown]
# #### Q3. Find from which age group most of the employees belong to.

# %%
df3=pd.DataFrame({"Counts":df.Age.value_counts()}).reset_index()
df3
# Out:
#     Age  Counts
# 0    24      47
# 1    25      46
# 2    27      41
# 3    23      41
# 4    26      36
# 5    28      31
# 6    30      31
# 7    29      28
# 8    22      26
# 9    31      22
# 10   20      19
# 11   21      19
# 12   33      14
# 13   32      13
# 14   34      10
# 15   36      10
# 16   35       9
# 17   37       4
# 18   38       4
# 19   40       3
# 20   39       2
# 21   19       2

# %% [markdown]
# ### Data story
# created a new dataframe called df3 with "age" and the no.of employees in each age category as 2 columns.

# %%
plt.hist(df['Age'], bins = [15,20,25,30,35,40,45]) 
plt.xlabel('Age')
plt.ylabel('No of Employees')
plt.title('Number of Employees in Each Age Group')
plt.show()

# %% [markdown]
# ### Data story
# We have used a histogram to plot the no. of emplyees within each age category with x axis representing Age category and y-axis "No. of employees".
#
# The above plot shows that the maximum no. of employees are within the age group of 25-30.

# %% [markdown]
# #### Q4. Find out under which team and position, spending in terms of salary is high.

# %%
grouped_df = df.groupby(['Team', 'Position'])['Salary'].sum().reset_index()
sorted_df = grouped_df.sort_values(by='Salary', ascending=False)
sorted_df['Abbreviation'] = sorted_df['Team'].apply(lambda x: ''.join(word[0] for word in x.split()))
sorted_df
# Out:
#                    Team Position      Salary Abbreviation
# 67   Los Angeles Lakers       SF  31866445.0          LAL
# 75           Miami Heat       PF  31538671.0           MH
# 53      Houston Rockets       SG  28122883.0           HR
# 116        Phoenix Suns       PG  28002998.0           PS
# 37       Denver Nuggets       SF  27982771.0           DN
# ..                  ...      ...         ...          ...
# 82      Milwaukee Bucks       SF   3104287.0           MB
# 112  Philadelphia 76ers       SF   1845059.0           P7
# 125    Sacramento Kings       PF   1370152.0           SK
# 74           Miami Heat        C    981348.0           MH
# 107       Orlando Magic       SF    845059.0           OM
#
# [149 rows x 4 columns]

# %% [markdown]
# ### Data story
# Here we have created a data frame with the columns Team, Position, Salary and Abbreviation. The column "Salary" displays the sum of salaries of all employees of a particular position within a team. The data is displayed in descending order with respect to the values in "Salary".

# %%
plt.figure(figsize=(20, 30))
plt.barh(y=sorted_df['Abbreviation'] + ' - ' + sorted_df['Position'],width=sorted_df['Salary'],color=plt.cm.tab20c.colors)
plt.xlabel('Salary')
plt.ylabel('Team-Position')
plt.title('Position vs Salary Graph')
plt.show()

# %% [markdown]
# ### Data story
# here is the Bar graph representation of Position within a team and the salary. Y axis represents each position in the team and X axis represents salary.

# %% [markdown]
# #### Q5. Find if there is any correlation between age and salary , represent it visually.

# %%
plt.figure(figsize=(10, 10))
sns.scatterplot(x='Age', y='Salary', data=df)
plt.show()

# %% [markdown]
# ### Data story
# Used a Scatter plot to represent the correlation between Age and Salary

# %% [markdown]
# ## Results and observations
# ### Data Preprocessing:
# 1. Used info() method to get details regarding the dataset and the following observations were made. It has 458 rows and 9 columns (Name, Team ,Number , Position , Age, Height, Weight, College, Salary). The columns "College" and "Salary" is having few null values. The rest of the columns has no null values.
# 2. Checked for null values in the dataset and displayed the total no. of null values in each column. It was observed that the columns, "College" and "Salary" is having 84 and 11 null values respectively.
# 3. Replaced all null values with the median values of respective columns.

# %% [markdown]
# ### Data Visualisation:
# 1. Created a data frame with the following columns; Team and Count. Count shows the no. of employees in each team. Plotted a bar graph to visualize the same. It was observed that the team "New Orleans Pelicans" has the highest number of employees.
# 2. Percentage split of employees among the team is calculated by taking the count of employees within a team divided by total no. of employees multiplied by 100. A pie chart is used to visualize the same. It is observed that employees at New Orleans Pelicans comprises of almost 4% of total employee strength. For that we used a line graph and a pie chart.
# 3. Calculated the no. of employees in each position. Used a bar graph to visualize the same. It is observed that majority of employees belong to the position "SG".
# 4. Calculated the counts of employees of each age group. Created a data frame to display the same and also used a histogram to visually represent it. It was observed that most of employees belong to age group 24-30.
# 5. Created a dataframe by grouping "Team" and "Position" and found the sum of salaries of employees in the same position within a team. This data is visualized using a bar graph and it is observed that in terms of salary , "SF" position in the team "Los Angeles Lakers " spends the highest.
# 6. Plotted a correlation graph to show the relation between Age and Salary. No particulat relation is observed between Age and Salary of an employee. Most of employee salary ranges below 1,00,00,000.
